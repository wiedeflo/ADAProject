# %%
'''
File name: project.ipynb
Author: ..., Mohamed Ndoye, Raphael Strebel
Date created: 03/11/2019
Date last modified: ...
Python Version: 3.7.4
'''

import pandas as pd
from sodapy import Socrata
from utils import load_datasets

# Set auto-reload 
# %load_ext autoreload
# %autoreload 2

# %%
# useful : https://www.sustainabilist.com/blog/chicago-data-analysis-a-internship-project

CITY_OF_CHICAGO_URL = 'data.cityofchicago.org'
FOOD_INSPECTION_DB_IDENTIFIER = '4ijn-s7e5'
DB_LINES_LIMIT = 50000

food_inspections = load_datasets.load_chicago_df(FOOD_INSPECTION_DB_IDENTIFIER, DB_LINES_LIMIT, CITY_OF_CHICAGO_URL)
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.

# %%
food_inspections.head()
# Out:
#   inspection_id                         dba_name license_  facility_type  \
# 0       2320923                            SLICE  2698443     Restaurant
# 1       2320916  ST. CONSTANCE ELEMENTARY SCHOOL  1878492         School
# 2       2320963                 LAS ISLAS MARIAS  1095992     Restaurant
# 3       2320977      TODD APPEL BAR AND COCKTAIL  2589615  Grocery Store
# 4       2320927             Sayre Language Acad.    29271         School
#
#               risk              address     city state    zip  \
# 0    Risk 1 (High)   303 E SUPERIOR ST   CHICAGO    IL  60611
# 1    Risk 1 (High)       5841 W STRONG   CHICAGO    IL  60630
# 2    Risk 1 (High)    4770 W GRAND AVE   CHICAGO    IL  60639
# 3  Risk 2 (Medium)  5868 N LINCOLN AVE   CHICAGO    IL  60659
# 4    Risk 1 (High)      1850 N Newland   CHICAGO    IL  60707
#
#            inspection_date inspection_type   results  \
# 0  2019-11-01T00:00:00.000         License      Pass
# 1  2019-11-01T00:00:00.000         Canvass  No Entry
# 2  2019-11-01T00:00:00.000       Complaint      Fail
# 3  2019-11-01T00:00:00.000         Canvass  No Entry
# 4  2019-11-01T00:00:00.000         Canvass      Fail
#
#                                           violations            latitude  \
# 0  51. PLUMBING INSTALLED; PROPER BACKFLOW DEVICE...  41.895692401410514
# 1                                                NaN  41.970175532686525
# 2  10. ADEQUATE HANDWASHING SINKS PROPERLY SUPPLI...   41.91399920930635
# 3                                                NaN   41.98805967591636
# 4  10. ADEQUATE HANDWASHING SINKS PROPERLY SUPPLI...   41.91412360237105
#
#             longitude                                           location  \
# 0  -87.62014286048188  {'latitude': '-87.62014286048188', 'longitude'...
# 1  -87.77509944904432  {'latitude': '-87.77509944904432', 'longitude'...
# 2  -87.74586369218258  {'latitude': '-87.74586369218258', 'longitude'...
# 3  -87.70370445181302  {'latitude': '-87.70370445181302', 'longitude'...
# 4  -87.79875666766955  {'latitude': '-87.79875666766955', 'longitude'...
#
#                           aka_name
# 0                              NaN
# 1  ST. CONSTANCE ELEMENTARY SCHOOL
# 2                 LAS ISLAS MARIAS
# 3      TODD APPEL BAR AND COCKTAIL
# 4             Sayre Language Acad.

# %%
# Don't know why we can't load like this...
FOOD_INSPECTIONS_PATH = 'data/chicago-food-inspections/food-inspections.csv'
food_inspections_col_names = ['inspection_id', 'DBA_name', 'AKA_name', 'license_num', 'facility_type', 'risk', 
                              'address', 'city', 'state', 'zip', 'inspection_date', 'inspection_type', 'result', 
                              'violations', 'lat', 'lng', 'location', 'historical_wards', 'zip_codes', 
                              'community_areas', 'census_tracts', 'wards']
food_inspections_DF = pd.read_csv(FOOD_INSPECTIONS_PATH, sep = '\t', header = 0, 
                   names = food_inspections_col_names, index_col = None, error_bad_lines=False
                   )
# Out:
# b'Skipping line 59: expected 1 fields, saw 2\nSkipping line 147: expected 1 fields, saw 2\nSkipping line 256: expected 1 fields, saw 2\nSkipping line 285: expected 1 fields, saw 2\nSkipping line 296: expected 1 fields, saw 3\nSkipping line 392: expected 1 fields, saw 2\nSkipping line 461: expected 1 fields, saw 11\nSkipping line 932: expected 1 fields, saw 2\nSkipping line 1034: expected 1 fields, saw 2\nSkipping line 1050: expected 1 fields, saw 2\nSkipping line 1101: expected 1 fields, saw 17\nSkipping line 1215: expected 1 fields, saw 5\nSkipping line 1